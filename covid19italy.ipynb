# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\Kishore\Desktop\file\covid19_italy_province.csv')
df.head(10)
# Out:
#    SNo                 Date Country  RegionCode  RegionName  ProvinceCode  \
# 0    0  2020-02-24T18:00:00     ITA          13     Abruzzo            66
# 1    1  2020-02-24T18:00:00     ITA          13     Abruzzo            67
# 2    2  2020-02-24T18:00:00     ITA          13     Abruzzo            68
# 3    3  2020-02-24T18:00:00     ITA          13     Abruzzo            69
# 4    4  2020-02-24T18:00:00     ITA          13     Abruzzo           979
# 5    5  2020-02-24T18:00:00     ITA          17  Basilicata            76
# 6    6  2020-02-24T18:00:00     ITA          17  Basilicata            77
# 7    7  2020-02-24T18:00:00     ITA          17  Basilicata           980
# 8    8  2020-02-24T18:00:00     ITA          18    Calabria            78
# 9    9  2020-02-24T18:00:00     ITA          18    Calabria            79
#
#                            ProvinceName ProvinceAbbreviation   Latitude  \
# 0                              L'Aquila                   AQ  42.351222
# ...

# %%
df.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'ProvinceCode',
#        'ProvinceName', 'ProvinceAbbreviation', 'Latitude', 'Longitude',
#        'TotalPositiveCases'],
#       dtype='object')

# %%
df.tail()
# Out:
#          SNo                 Date Country  RegionCode RegionName  \
# 27531  27531  2020-09-12T17:00:00     ITA           5     Veneto
# 27532  27532  2020-09-12T17:00:00     ITA           5     Veneto
# 27533  27533  2020-09-12T17:00:00     ITA           5     Veneto
# 27534  27534  2020-09-12T17:00:00     ITA           5     Veneto
# 27535  27535  2020-09-12T17:00:00     ITA           5     Veneto
#
#        ProvinceCode                          ProvinceName  \
# 27531            27                               Venezia
# 27532            28                                Padova
# 27533            29                                Rovigo
# 27534           899    Fuori Regione / Provincia Autonoma
# 27535           999  In fase di definizione/aggiornamento
#
#       ProvinceAbbreviation   Latitude  Longitude  TotalPositiveCases
# 27531                   VE  45.434905  12.338452                3517
# 27532                   PD  45.406930  11.876087                4910
# ...

# %%
df.describe()
# Out:
#                 SNo    RegionCode  ProvinceCode      Latitude     Longitude  \
# count  27536.000000  27536.000000  27536.000000  21614.000000  21614.000000
# mean   13767.500000     10.453806    249.101031     42.908522     12.096599
# std     7949.102842      6.035008    374.065824      2.631570      2.660608
# min        0.000000      1.000000      1.000000     36.925092      7.320149
# 25%     6883.750000      5.000000     35.000000     40.914047      9.828190
# 50%    13767.500000      9.000000     69.000000     43.715532     12.104734
# 75%    20651.250000     16.000000    103.000000     45.185093     14.167546
# max    27535.000000     22.000000    999.000000     46.499335     18.171897
#
#        TotalPositiveCases
# count        27536.000000
# mean          1415.969749
# std           2840.717047
# min              0.000000
# 25%             64.000000
# 50%            442.000000
# 75%           1440.250000
# max          27496.000000

# %%
df.isnull().sum()
# Out:
# SNo                        0
# Date                       0
# Country                    0
# RegionCode                 0
# RegionName                 0
# ProvinceCode               0
# ProvinceName               0
# ProvinceAbbreviation    6124
# Latitude                5922
# Longitude               5922
# TotalPositiveCases         0
# dtype: int64

# %%
sns.relplot(x='ProvinceName',y='TotalPositiveCases',kind='line',data=df)

# %%
sns.pairplot(df)
